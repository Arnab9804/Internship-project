# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.head(5)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail (5)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# ...

# %%
df.sample(5)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 449  CS-97450      A     A-      A         A      A     A+      B     A-
# 217  CS-97218     D+      C     C+         D      D     B+     C-     C-
# 526  CS-97527      B      C     A-         C     B-     B+     B-      D
# 210  CS-97211      D      D      D        D+     D+     B+      D      D
# 64   CS-97065     B-     B-     A-        D+     C+     A-      C     A-
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 449      A  ...     A+     A+      A     A-      A     A-     A-     A-
# 217     A-  ...     D+     C-     B-      C      B     A-      C      D
# 526     B-  ...     B+     B-     B+      C     D+      C     B+      B
# 210     C-  ...     C-     C-     C+      C     D+      C     B-     C-
# 64      A-  ...      C     C+     B-      C     A-     A-     B-     A-
#
#     CS-412   CGPA
# 449      A  3.908
# 217     A-  1.909
# 526      B  2.659
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# 1. It seems like this dataset consists of two types of data like object and float64
#
# 2. Also i can see some missing value to confirm the null value i have to check with isnull & heatmap graph

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
sns.heatmap (df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# I can confirm the presence of missing values in my dataset and i have to impute them with the mode or mean.

# %%
print (df['CY-105'].mode()[0])
print (df['HS-105/12'].mode()[0])
print (df['MT-111'].mode()[0])
# Out:
# A
# A
# A-

# %%
df['CY-105']=df['CY-105'].fillna(df['CY-105'].mode()[0])
df['HS-105/12']=df['HS-105/12'].fillna(df['HS-105/12'].mode()[0])
df['MT-111']=df['MT-111'].fillna(df['MT-111'].mode()[0])

# %%
list=['CS-106','EL-102','EE-119','EE-119','CS-107','HS-205/20','MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214',
      'EE-217','CS-212','CS-215','MT-331','EF-303','HS-304','CS-301','CS-302','TC-383','MT-442','EL-332','CS-318','CS-306',
      'CS-312','CS-317','CS-403','CS-421','CS-406','CS-414','CS-419','CS-423','CS-412','ME-107']
       
       
       
       

for i in list:
    df[i]=df[i].fillna(df[i].mode()[0])

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# I've successfully removed all missing values by imputing them with the mode

# %%
df.nunique().to_frame('No of of unique value')
# Out:
#            No of of unique value
# Seat No.                     571
# PH-121                        13
# HS-101                        12
# CY-105                        13
# HS-105/12                     13
# MT-111                        13
# CS-105                        11
# CS-106                        13
# EL-102                        13
# EE-119                        12
# ME-107                        13
# CS-107                        14
# HS-205/20                     13
# MT-222                        14
# EE-222                        13
# MT-224                        14
# CS-210                        14
# CS-211                        14
# CS-203                        13
# CS-214                        13
# EE-217                        13
# CS-212                        12
# CS-215                        14
# MT-331                        12
# EF-303                        12
# HS-304                        14
# CS-301                        12
# ...

# %% [markdown]
# 1. The target variable, CGPA, exhibits a substantial number of unique values, and its data type is identified as float64. Given these characteristics, it is reasonable to categorize the task associated with predicting CGPA as a regression problem.
# 2. The continuous and numerical nature of the CGPA values aligns with the typical characteristics of regression tasks, where the objective is to predict a continuous output.

# %%
for i in df.columns:
    print (df[i].value_counts())
    print ('\n')
# Out:
# CS-97001    1
# CS-97384    1
# CS-97378    1
# CS-97379    1
# CS-97380    1
#            ..
# CS-97185    1
# CS-97184    1
# CS-97183    1
# CS-97182    1
# CS-97571    1
# Name: Seat No., Length: 571, dtype: int64
#
#
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64
#
#
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64
#
#
# A     178
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64
#
#
# A     97
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64
#
#
# A-    107
# A     100
# B-     70
# B+     62
# ...

# %% [markdown]
# # Encoding Process

# %%
from sklearn.preprocessing import LabelEncoder

list=['PH-121','HS-101','CY-105','HS-105/12','MT-111','CS-105','CS-106','EL-102','EE-119','ME-107','CS-107','HS-205/20',
      'MT-222','EE-222','MT-224','CS-210','CS-211','CS-203','CS-214','EE-217','CS-212','CS-215','MT-331','EF-303','HS-304',
      'CS-301','CS-302','TC-383','MT-442','EL-332','CS-318','CS-306','CS-312','CS-317','CS-403','CS-421','CS-406','CS-414',
      'CS-419','CS-423','CS-412']

le=LabelEncoder()
for i in list:
    df[i]=le.fit_transform(df[i])

# %%
df.sample (5)
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 529  CS-97530       1       0       0          0       0       0       4
# 545  CS-97546       3       3       0          0       2       2       2
# 483  CS-97484       2       4       0          1       2       1       2
# 58   CS-97059       4       3       7          2       2       2       8
# 290  CS-97291       3       6       3          7       4       3       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# 529       0       0  ...       1       1       0       0       1       4
# 545       9       2  ...       3       3       0       4       3       6
# 483       0       0  ...       0       3       1       2       4       3
# 58        3       2  ...       5       2       5       8       2       0
# 290       4       4  ...       1       3       2       5       2       0
#
#      CS-419  CS-423  CS-412   CGPA
# 529       4       0       0  3.876
# ...

# %% [markdown]
# # Correlation Check

# %%
plt.figure(figsize=(50,35))
heatmap=sns.heatmap(df.corr(),annot= True)
plt.title ('Correlation Check',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Correlation Check')

# %%
df.hist(bins=10,figsize=(40,30))
# Out:
# array([[<Axes: title={'center': 'PH-121'}>,
#         <Axes: title={'center': 'HS-101'}>,
#         <Axes: title={'center': 'CY-105'}>,
#         <Axes: title={'center': 'HS-105/12'}>,
#         <Axes: title={'center': 'MT-111'}>,
#         <Axes: title={'center': 'CS-105'}>],
#        [<Axes: title={'center': 'CS-106'}>,
#         <Axes: title={'center': 'EL-102'}>,
#         <Axes: title={'center': 'EE-119'}>,
#         <Axes: title={'center': 'ME-107'}>,
#         <Axes: title={'center': 'CS-107'}>,
#         <Axes: title={'center': 'HS-205/20'}>],
#        [<Axes: title={'center': 'MT-222'}>,
#         <Axes: title={'center': 'EE-222'}>,
#         <Axes: title={'center': 'MT-224'}>,
#         <Axes: title={'center': 'CS-210'}>,
#         <Axes: title={'center': 'CS-211'}>,
#         <Axes: title={'center': 'CS-203'}>],
#        [<Axes: title={'center': 'CS-214'}>,
#         <Axes: title={'center': 'EE-217'}>,
#         <Axes: title={'center': 'CS-212'}>,
# ...

# %% [markdown]
# I aim to enhance the graphical comprehension and facilitate univariate as well as bivariate analysis by strategically reducing the dimensionality of the dataset. To achieve this, I plan to leverage Principal Component Analysis (PCA) technique to streamline the dataset

# %%
df=df.drop('Seat No.',axis=1)
df
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df['CGPA'].value_counts()
# Out:
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: CGPA, Length: 491, dtype: int64

# %%
df['CGPA'].nunique()
# Out:
# 491

# %% [markdown]
# # Split The Data

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
print (x)
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
print (y)
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %% [markdown]
# # Traning & Testing the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxacc=0
maxre=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predict_lr=lr.predict(x_test)
    acc=r2_score(y_test,predict_lr)
    if acc>maxacc:
        maxacc=acc
        maxre=i
print('Maximum r2 score is:',maxacc,'Best Random Estate:',maxre)
# Out:
# Maximum r2 score is: 0.9643494726169242 Best Random Estate: 72

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=predict_lr,y=y_test)
# Out:
# <Axes: ylabel='CGPA'>

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor

from sklearn.model_selection import cross_val_score

# %%
def regressionModel(model):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=72)
    model.fit (x_train,y_train)
    print('Model traning Score:',model.score(x_train,y_train))
    pred_model=model.predict (x_test)
    print ('Best r2 score:',r2_score(pred_model,y_test))
    print ('Mean absolute Error Score:',mean_absolute_error(pred_model,y_test))
    print ('Mean squared error Score:', mean_squared_error(pred_model,y_test))
    print ('Root Mean squared error:',np.sqrt(mean_squared_error(pred_model,y_test)))
    
    
    score=cross_val_score(model,x,y,cv=7)
    print('CV Score:', np.mean(score))
    print ('Difference between r2 score and cv score:', r2_score(pred_model,y_test) - np.mean(score))

# %%
model=RandomForestRegressor()                                                                         # R2_Score: 0.92
regressionModel(model)                                                                                # CV Score: 0.90
# Out:
# Model traning Score: 0.9794878575327448
# Best r2 score: 0.9224162393324634
# Mean absolute Error Score: 0.1142584883720929
# Mean squared error Score: 0.024781666852325534
# Root Mean squared error: 0.15742193891680262
# CV Score: 0.8994102885466715
# Difference between r2 score and cv score: 0.02300595078579193

# %%
model=LinearRegression()                                                                              # R2_Score: 0.96
regressionModel(model)                                                                                # CV Score: 0.90
# Out:
# Model traning Score: 0.9139022616556756
# Best r2 score: 0.9651761999295531
# Mean absolute Error Score: 0.08938340774408551
# Mean squared error Score: 0.013741931476875207
# Root Mean squared error: 0.1172259846487766
# CV Score: 0.9017931069382039
# Difference between r2 score and cv score: 0.06338309299134914

# %%
model=DecisionTreeRegressor()                                                                         # R2_Score: 0.85
regressionModel(model)                                                                                # CV Score: 0.75
# Out:
# Model traning Score: 1.0
# Best r2 score: 0.8308402102233908
# Mean absolute Error Score: 0.18799999999999994
# Mean squared error Score: 0.06493731395348835
# Root Mean squared error: 0.25482800857340693
# CV Score: 0.7543275464993661
# Difference between r2 score and cv score: 0.07651266372402477

# %%
model=KNeighborsRegressor()                                                                         # R2_Score: 0.96
regressionModel(model)                                                                              # CV Score: 0.88
# Out:
# Model traning Score: 0.9142712169240712
# Best r2 score: 0.9657245720736791
# Mean absolute Error Score: 0.08414302325581392
# Mean squared error Score: 0.012396490465116273
# Root Mean squared error: 0.11133952786461901
# CV Score: 0.8878535250071632
# Difference between r2 score and cv score: 0.07787104706651593

# %%
model=Ridge()                                                                                       # R2_Score: 0.96
regressionModel(model)                                                                              # CV Score: 0.90
# Out:
# Model traning Score: 0.9139022436130492
# Best r2 score: 0.9652006132712591
# Mean absolute Error Score: 0.08935085255469434
# Mean squared error Score: 0.013731282016836963
# Root Mean squared error: 0.11718055306592884
# CV Score: 0.9018124016832832
# Difference between r2 score and cv score: 0.0633882115879758

# %%
model=Lasso()                                                                                       # R2_Score: -12.67
regressionModel(model)                                                                              # CV Score: 0.33
# Out:
# Model traning Score: 0.33484914041131697
# Best r2 score: -12.678275086265364
# Mean absolute Error Score: 0.4242155056363917
# Mean squared error Score: 0.2503153150084445
# Root Mean squared error: 0.50031521564754
# CV Score: 0.33373313188636644
# Difference between r2 score and cv score: -13.012008218151731

# %%
model=ExtraTreesRegressor()                                                                         # R2_Score: 0.95
regressionModel(model)                                                                              # CV Score: 0.92
# Out:
# Model traning Score: 1.0
# Best r2 score: 0.9521379703010305
# Mean absolute Error Score: 0.08737081395348822
# Mean squared error Score: 0.014695735516279071
# Root Mean squared error: 0.1212259688197173
# CV Score: 0.9292507456654241
# Difference between r2 score and cv score: 0.02288722463560644

# %%
model=SVR()                                                                                         # R2_Score: 0.97
regressionModel(model)                                                                              # CV Score: 0.91
# Out:
# Model traning Score: 0.9581722934535725
# Best r2 score: 0.9700606700300863
# Mean absolute Error Score: 0.07778518158705636
# Mean squared error Score: 0.010443394196904394
# Root Mean squared error: 0.10219292635453979
# CV Score: 0.912788305786092
# Difference between r2 score and cv score: 0.05727236424399429

# %%
model=SGDRegressor()                                                                                # R2_Score: 0.5
regressionModel(model)                                                                              # CV Score: 0.74
# Out:
# Model traning Score: -13.26157782075005
# Best r2 score: -0.6423892056205929
# Mean absolute Error Score: 2.070583818142296
# Mean squared error Score: 6.241381859941099
# Root Mean squared error: 2.498275777399505
# CV Score: 0.6110814910014035
# Difference between r2 score and cv score: -1.2534706966219964

# %% [markdown]
# After evaluating various regression models based on the difference in R2 scores and cross-validation scores, SVRr is identified as the most suitable model for the given dataset.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
prama={'kernel':['linear','poly','rbf','sigmoid'],
       'gamma':['scale','auto'],
       'coef0':[0.0,0.01,0.001],
      'shrinking':[True,False]}

# %%
gscv=GridSearchCV(SVR(),prama,cv=5)
gscv.fit (x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'coef0': [0.0, 0.01, 0.001],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                          'shrinking': [True, False]})

# %%
gscv.best_params_
# Out:
# {'coef0': 0.0, 'gamma': 'scale', 'kernel': 'linear', 'shrinking': True}

# %%
FinalModel=SVR(kernel='linear',gamma='scale',coef0=0.0,shrinking=True)
FinalModel.fit (x_train,y_train)
FinalModel_pred=FinalModel.predict(x_test)
print("Model Traning Score:",FinalModel.score(x_train,y_train))
print ('Best r2 Score:', r2_score(FinalModel_pred,y_test))

score=cross_val_score(FinalModel,x,y,cv=7)
print('CV Score:', np.mean(score))
print ('Difference between r2 score and cv score:', r2_score(FinalModel_pred,y_test) - np.mean(score))
# Out:
# Model Traning Score: 0.8983191776461499
# Best r2 Score: 0.9693771584465805
# CV Score: 0.9091259104408348
# Difference between r2 score and cv score: 0.06025124800574566

# %% [markdown]
# # Saving the Model

# %%
import joblib

# %%
joblib.dump(SVR,'SVR_model.obj')
# Out:
# ['SVR_model.obj']

# %% [markdown]
# # Checking Model

# %%
Best_fit_Model=joblib.load('SVR_model.obj')
Best_fit_Model
# Out:
# sklearn.svm._classes.SVR
