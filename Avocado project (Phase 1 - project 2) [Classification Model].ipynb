# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv('avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df['Date']=df['Date'].apply (pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
df['Month']=df['Date'].apply (lambda x:x.month)

# %%
df['Month']=df['Month'].map({1:'jAN',2:'FEB',3:'MARCH',4:'APRIL',5:'MAY',6:'JUNE',7:'JULY',8:'AUG',9:'SEPT',10:'OCT',11:'NOV',12:'DEC'})

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0          1.33      64236.62  1036.74   54454.85   48.16
# 1           1          1.35      54876.98   674.28   44638.81   58.33
# 2           2          0.93     118220.22   794.70  109149.67  130.50
# 3           3          1.08      78992.15  1132.00   71976.41   72.58
# 4           4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region Month
# 0  Albany   DEC
# 1  Albany   DEC
# 2  Albany   DEC
# 3  Albany   DEC
# 4  Albany   NOV

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region Month
# 0     8603.62       93.25          0.0  conventional  2015  Albany   DEC
# 1     9408.07       97.49          0.0  conventional  2015  Albany   DEC
# 2     8042.21      103.14          0.0  conventional  2015  Albany   DEC

# %%
df['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
print (df['year'].value_counts())
sns.countplot(df,x='year')
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64
# <Axes: xlabel='year', ylabel='count'>

# %%
print (df['type'].value_counts())
sns.countplot(df,x='type')
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64
# <Axes: xlabel='type', ylabel='count'>

# %%
print (df['region'].value_counts().reset_index()[:10])
plt.figure(figsize=(60,20))
sns.countplot(df,x='region')
# Out:
#                 index  region
# 0              Albany     338
# 1          Sacramento     338
# 2           Northeast     338
# 3  NorthernNewEngland     338
# 4             Orlando     338
# 5        Philadelphia     338
# 6       PhoenixTucson     338
# 7          Pittsburgh     338
# 8              Plains     338
# 9            Portland     338
# <Axes: xlabel='region', ylabel='count'>

# %%
type_val=df.groupby(['type','year','region','Month']).size().reset_index().rename(columns={0:'value_count'})
type_val
# Out:
#               type  year            region  Month  value_count
# 0     conventional  2015            Albany  APRIL            4
# 1     conventional  2015            Albany    AUG            5
# 2     conventional  2015            Albany    DEC            4
# 3     conventional  2015            Albany    FEB            4
# 4     conventional  2015            Albany   JULY            4
# ...            ...   ...               ...    ...          ...
# 4207       organic  2018              West  MARCH            4
# 4208       organic  2018              West    jAN            4
# 4209       organic  2018  WestTexNewMexico    FEB            4
# 4210       organic  2018  WestTexNewMexico  MARCH            4
# 4211       organic  2018  WestTexNewMexico    jAN            4
#
# [4212 rows x 5 columns]

# %%
sns.barplot(type_val,x='year',y='value_count',hue='type',palette='bright')
# Out:
# <Axes: xlabel='year', ylabel='value_count'>

# %%
year_val=df['year'].value_counts().values
year_val
# Out:
# array([5722, 5616, 5615, 1296], dtype=int64)

# %%
year_name=df['year'].value_counts().index
year_name
# Out:
# Int64Index([2017, 2016, 2015, 2018], dtype='int64')

# %%
plt.pie(year_val,labels=year_name,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2c9b3fbd490>,
# ...
#  [Text(0.6081028103162422, 0.9166302264738428, '2017'),
#   Text(-1.0770368663861618, 0.2235879881502522, '2016'),
#   Text(0.1730223708607895, -1.0863071661283064, '2015'),
#   Text(1.0727358423524513, -0.2433881930833478, '2018')],
#  [Text(0.33169244199067754, 0.4999801235311869, '31.36%'),
#   Text(-0.5874746543924518, 0.12195708444559208, '30.77%'),
#   Text(0.09437583865133972, -0.5925311815245307, '30.77%'),
#   Text(0.5851286412831552, -0.1327571962272806, '7.10%')])

# %%
df['Month'].nunique()
# Out:
# 12

# %%
print (type_val['Month'].value_counts())
sns.countplot(type_val,x='Month',palette='bright')
# Out:
# FEB      432
# MARCH    432
# jAN      432
# APRIL    324
# AUG      324
# DEC      324
# JULY     324
# JUNE     324
# MAY      324
# NOV      324
# OCT      324
# SEPT     324
# Name: Month, dtype: int64
# <Axes: xlabel='Month', ylabel='count'>

# %%
sns.histplot(df,x='AveragePrice',kde=True)
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Count'>

# %%
plt.figure(figsize=(20,15))
sns.barplot(df,x='AveragePrice',y='region',palette='bright')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='region'>

# %%
plt.figure(figsize=(20,15))
sns.barplot(df,x='AveragePrice',y='Month',palette='bright')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Month'>

# %%
df_cor=df.corr()
df_cor
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df_cor,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

# %%
list=['type','region','Month']
la=LabelEncoder()
for i in list:
    df[i]=la.fit_transform(df[i])

# %%
df.head(3)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# 0     8603.62       93.25          0.0     0  2015       0      2
# 1     9408.07       97.49          0.0     0  2015       0      2
# 2     8042.21      103.14          0.0     0  2015       0      2

# %%
plt.figure(figsize=(10,8))
df_cor=df.corr()
sns.heatmap(df_cor,annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=15:
        plt.subplot(5,4,p)
        sns.histplot(df[i],kde=True)
        plt.xlabel(i)
    p+=1
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(5,4),figsize=(15,20))
# Out:
# AveragePrice       Axes(0.125,0.747241;0.168478x0.132759)
# Total Volume    Axes(0.327174,0.747241;0.168478x0.132759)
# 4046            Axes(0.529348,0.747241;0.168478x0.132759)
# 4225            Axes(0.731522,0.747241;0.168478x0.132759)
# 4770               Axes(0.125,0.587931;0.168478x0.132759)
# Total Bags      Axes(0.327174,0.587931;0.168478x0.132759)
# Small Bags      Axes(0.529348,0.587931;0.168478x0.132759)
# Large Bags      Axes(0.731522,0.587931;0.168478x0.132759)
# XLarge Bags        Axes(0.125,0.428621;0.168478x0.132759)
# type            Axes(0.327174,0.428621;0.168478x0.132759)
# year            Axes(0.529348,0.428621;0.168478x0.132759)
# region          Axes(0.731522,0.428621;0.168478x0.132759)
# Month               Axes(0.125,0.26931;0.168478x0.132759)
# dtype: object

# %%
import scipy
from scipy.stats import zscore

# %%
z=np.abs (zscore(df))
z
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0          0.188689      0.227716  0.230816  0.199902  0.212091    0.234170
# 1          0.139020      0.230427  0.231103  0.208054  0.211997    0.233350
# 2          1.182069      0.212085  0.231007  0.154478  0.211325    0.234730
# 3          0.809551      0.223444  0.230741  0.185350  0.211864    0.237096
# 4          0.312861      0.231538  0.230891  0.208719  0.211834    0.236718
# ...             ...           ...       ...       ...       ...         ...
# 18244      0.556347      0.241373  0.230017  0.243857  0.212540    0.229301
# 18245      0.755023      0.242296  0.230693  0.242277  0.212540    0.233594
# 18246      1.152375      0.242331  0.230693  0.243090  0.205766    0.233463
# 18247      1.301382      0.241625  0.230428  0.242651  0.205774    0.231866
# 18248      0.531512      0.241253  0.229347  0.243170  0.210450    0.230807
#
# ...

# %%
thresold=3
print (np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
z.iloc[346,2]
# Out:
# 3.199410614794124

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# ...

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# ...

# %%
(18249-17651)/18249*100
# Out:
# 3.276891884486821

# %% [markdown]
# ##### After removing outliers, the percentage of data loss is 3.27%, a level that is acceptable and manageable for me.

# %%
df=df_new
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# ...

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# Month          -0.004340
# dtype: float64

# %%
df['Total Volume']=np.sqrt(df['Total Volume'])
df['4046']=np.sqrt(df['4046'])
df['4225']=np.sqrt(df['4225'])
df['4770']=np.sqrt(df['4770'])
df['Total Bags']=np.sqrt(df['Total Bags'])
df['Small Bags']=np.sqrt(df['Small Bags'])
df['Large Bags']=np.sqrt(df['Large Bags'])
df['XLarge Bags']=np.sqrt(df['XLarge Bags'])

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    1.963864
# 4046            2.497504
# 4225            2.128505
# 4770            2.636658
# Total Bags      2.010691
# Small Bags      2.093752
# Large Bags      2.236756
# XLarge Bags     3.312484
# type           -0.037741
# year            0.229976
# region          0.012798
# Month          -0.004340
# dtype: float64

# %%
df['Total Volume']=np.sqrt(df['Total Volume'])
df['4046']=np.sqrt(df['4046'])
df['4225']=np.sqrt(df['4225'])
df['4770']=np.sqrt(df['4770'])
df['Total Bags']=np.sqrt(df['Total Bags'])
df['Small Bags']=np.sqrt(df['Small Bags'])
df['Large Bags']=np.sqrt(df['Large Bags'])
df['XLarge Bags']=np.sqrt(df['XLarge Bags'])

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    0.886698
# 4046            1.082068
# 4225            0.843699
# 4770            1.072804
# Total Bags      0.836412
# Small Bags      0.793773
# Large Bags      0.728979
# XLarge Bags     1.776124
# type           -0.037741
# year            0.229976
# region          0.012798
# Month          -0.004340
# dtype: float64

# %%
df['4046']=np.sqrt(df['4046'])

df['4770']=np.sqrt(df['4770'])

df['XLarge Bags']=np.sqrt(df['XLarge Bags'])

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    0.886698
# 4046            0.234534
# 4225            0.843699
# 4770            0.029629
# Total Bags      0.836412
# Small Bags      0.793773
# Large Bags      0.728979
# XLarge Bags     1.099717
# type           -0.037741
# year            0.229976
# region          0.012798
# Month          -0.004340
# dtype: float64

# %%
df['XLarge Bags']=np.cbrt(df['XLarge Bags'])

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    0.886698
# 4046            0.234534
# 4225            0.843699
# 4770            0.029629
# Total Bags      0.836412
# Small Bags      0.793773
# Large Bags      0.728979
# XLarge Bags     0.799122
# type           -0.037741
# year            0.229976
# region          0.012798
# Month          -0.004340
# dtype: float64

# %% [markdown]
# # Split the data

# %%
y=df['type']
x=df[['AveragePrice','Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','year','region','Month']]

# %%
print (x.shape)
print (y.shape)
# Out:
# (17651, 12)
# (17651,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.195352     -0.303686 -0.684812  0.158329 -0.109204   -0.636048
# 1         -0.143510     -0.364136 -0.782796  0.070375 -0.080963   -0.605756
# 2         -1.232207     -0.045732 -0.745990  0.502798  0.045416   -0.657941
# 3         -0.843387     -0.220612 -0.664133  0.289379 -0.047908   -0.765265
# 4         -0.324959     -0.391173 -0.707225  0.062584 -0.041276   -0.746177
# ...             ...           ...       ...       ...       ...         ...
# 17646      0.582289     -0.745211 -0.518700 -0.913277 -1.274378   -0.479484
# 17647      0.789660     -0.801803 -0.651937 -0.746965 -1.274378   -0.614564
# 17648      1.204402     -0.804141 -0.651893 -0.820156  0.361748   -0.609813
# 17649      1.359930     -0.759808 -0.591892 -0.778390  0.361487   -0.555515
# 17650      0.556367     -0.738444 -0.428489 -0.828515  0.138043   -0.522665
#
# ...

# %% [markdown]
# # Checking VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF factor']=[variance_inflation_factor (x.values,i) for i in range (len (x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF factor      Features
# 0     1.722552  AveragePrice
# 1    74.195754  Total Volume
# 2     8.063620          4046
# 3    17.687445          4225
# 4     3.309985          4770
# 5    70.443475    Total Bags
# 6    40.718926    Small Bags
# 7     6.109741    Large Bags
# 8     1.934495   XLarge Bags
# 9     1.399139          year
# 10    1.077698        region
# 11    1.007901         Month

# %%
y=df['type']
x=df[['AveragePrice','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','year','region','Month']]

# %%
print (x.shape)
print (y.shape)
# Out:
# (17651, 11)
# (17651,)

# %%
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#        AveragePrice      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.195352 -0.684812  0.158329 -0.109204   -0.636048   -0.475351
# 1         -0.143510 -0.782796  0.070375 -0.080963   -0.605756   -0.444324
# 2         -1.232207 -0.745990  0.502798  0.045416   -0.657941   -0.498319
# 3         -0.843387 -0.664133  0.289379 -0.047908   -0.765265   -0.610873
# 4         -0.324959 -0.707225  0.062584 -0.041276   -0.746177   -0.594375
# ...             ...       ...       ...       ...         ...         ...
# 17646      0.582289 -0.518700 -0.913277 -1.274378   -0.479484   -0.324148
# 17647      0.789660 -0.651937 -0.746965 -1.274378   -0.614564   -0.462121
# 17648      1.204402 -0.651893 -0.820156  0.361748   -0.609813   -0.446428
# 17649      1.359930 -0.591892 -0.778390  0.361487   -0.555515   -0.391043
# 17650      0.556367 -0.428489 -0.828515  0.138043   -0.522665   -0.356627
#
#        Large Bags  XLarge Bags      year    region     Month
# ...

# %%
vif=pd.DataFrame()
vif['VIF Factor']=[variance_inflation_factor (x.values,i) for i in range (len (x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Factor      Features
# 0     1.670916  AveragePrice
# 1     3.894519          4046
# 2     5.295717          4225
# 3     3.277714          4770
# 4    63.697337    Total Bags
# 5    40.002126    Small Bags
# 6     6.091160    Large Bags
# 7     1.930827   XLarge Bags
# 8     1.371575          year
# 9     1.073872        region
# 10    1.007777         Month

# %%
df=df.drop('Total Bags',axis=1)

# %%
df.head(2)
# Out:
#    AveragePrice      4046       4225      4770  Small Bags  Large Bags  \
# 0          1.33  2.382093  15.275982  1.623065    9.630976    3.107508
# 1          1.35  2.257382  14.535439  1.662404    9.848614    3.142245
#
#    XLarge Bags  type  year  region  Month
# 0          0.0     0  2015       0      2
# 1          0.0     0  2015       0      2

# %%
y=df['type']
x=df[['AveragePrice','4046','4225','4770','Small Bags','Large Bags','XLarge Bags','year','region','Month']]

# %%
print (x.shape)
print (y.shape)
# Out:
# (17651, 10)
# (17651,)

# %%
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#        AveragePrice      4046      4225      4770  Small Bags  Large Bags  \
# 0         -0.195352 -0.684812  0.158329 -0.109204   -0.475351   -0.800692
# 1         -0.143510 -0.782796  0.070375 -0.080963   -0.444324   -0.794989
# 2         -1.232207 -0.745990  0.502798  0.045416   -0.498319   -0.787671
# 3         -0.843387 -0.664133  0.289379 -0.047908   -0.610873   -0.752539
# 4         -0.324959 -0.707225  0.062584 -0.041276   -0.594375   -0.695258
# ...             ...       ...       ...       ...         ...         ...
# 17646      0.582289 -0.518700 -0.913277 -1.274378   -0.324148   -0.562450
# 17647      0.789660 -0.651937 -0.746965 -1.274378   -0.462121   -0.613897
# 17648      1.204402 -0.651893 -0.820156  0.361748   -0.446428   -0.892155
# 17649      1.359930 -0.591892 -0.778390  0.361487   -0.391043   -0.874303
# 17650      0.556367 -0.428489 -0.828515  0.138043   -0.356627   -0.940111
#
#        XLarge Bags      year    region     Month
# ...

# %%
vif=pd.DataFrame()
vif['VIF Factor']=[variance_inflation_factor (x.values,i) for i in range (len (x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF Factor      Features
# 0    1.602008  AveragePrice
# 1    3.893844          4046
# 2    5.025820          4225
# 3    3.274639          4770
# 4    5.517188    Small Bags
# 5    2.104054    Large Bags
# 6    1.930124   XLarge Bags
# 7    1.350075          year
# 8    1.073572        region
# 9    1.007668         Month

# %% [markdown]
# ##### Again Checking Correlation

# %%
df_cor=df.corr()
plt.figure(figsize=(15,8))
sns.heatmap(df_cor,annot=True)
# Out:
# <Axes: >

# %%
df['type'].value_counts()
# Out:
# 1    8992
# 0    8659
# Name: type, dtype: int64

# %% [markdown]
# # OVERSAMPLING (SMOTE)

# %%
import imblearn
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x_new,y_new=sm.fit_resample(x,y)

# %%
print(y.value_counts())
print(y_new.value_counts())
# Out:
# 1    8992
# 0    8659
# Name: type, dtype: int64
# 0    8992
# 1    8992
# Name: type, dtype: int64

# %%
x,y=x_new,y_new

# %%
print(y.value_counts())
# Out:
# 0    8992
# 1    8992
# Name: type, dtype: int64

# %% [markdown]
# # Data Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.linear_model import LogisticRegression

# %%
maxAcc=0
maxRE=0
for i in range (1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lg=LogisticRegression()
    lg.fit (x_train,y_train)
    pred_lg=lg.predict(x_test)
    acc=accuracy_score(pred_lg,y_test)
    if acc>maxAcc:
        maxAcc=acc
        maxRE=i

print ("Best accuracy score:",maxAcc,"Best random Estate:",maxRE)
# Out:
# Best accuracy score: 0.9651593773165308 Best random Estate: 114

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import cross_val_score

# %%
def classification_Model(model):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=114)
    model.fit (x_train, y_train)
    pred_model=model.predict(x_test)
    print ("Best Model Score:",model.score(x_train,y_train))

    print ('Best Accuracy score:',accuracy_score(pred_model,y_test))
    
    print ('Best Classification Report:', classification_report(pred_model,y_test))
    
    print ('Best confusion Matrix:', confusion_matrix(pred_model,y_test))
    
    print ('\n')
    
    score=cross_val_score(model,x,y,cv=7)
    print ("Best CV Score:",np.mean(score))

# %%
model=LogisticRegression()
classification_Model(model)
# Out:
# Best Model Score: 0.955830950111217
# Best Accuracy score: 0.9651593773165308
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      2691
#            1       0.97      0.96      0.97      2705
#
#     accuracy                           0.97      5396
#    macro avg       0.97      0.97      0.97      5396
# weighted avg       0.97      0.97      0.97      5396
#
# Best confusion Matrix: [[2604   87]
#  [ 101 2604]]
#
#
# Best CV Score: 0.9528459325290141

# %%
model=RandomForestClassifier()
classification_Model(model)
# Out:
# Best Model Score: 1.0
# Best Accuracy score: 0.9968495181616012
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      2716
#            1       0.99      1.00      1.00      2680
#
#     accuracy                           1.00      5396
#    macro avg       1.00      1.00      1.00      5396
# weighted avg       1.00      1.00      1.00      5396
#
# Best confusion Matrix: [[2702   14]
#  [   3 2677]]
#
#
# Best CV Score: 0.9894900739587388

# %%
model=ExtraTreesClassifier()
classification_Model(model)
# Out:
# Best Model Score: 1.0
# Best Accuracy score: 0.9985174203113417
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2709
#            1       1.00      1.00      1.00      2687
#
#     accuracy                           1.00      5396
#    macro avg       1.00      1.00      1.00      5396
# weighted avg       1.00      1.00      1.00      5396
#
# Best confusion Matrix: [[2703    6]
#  [   2 2685]]
#
#
# Best CV Score: 0.9878775263537916

# %%
model=GaussianNB()
classification_Model(model)
# Out:
# Best Model Score: 0.9393867175087385
# Best Accuracy score: 0.9434766493699036
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94      2636
#            1       0.96      0.93      0.94      2760
#
#     accuracy                           0.94      5396
#    macro avg       0.94      0.94      0.94      5396
# weighted avg       0.94      0.94      0.94      5396
#
# Best confusion Matrix: [[2518  118]
#  [ 187 2573]]
#
#
# Best CV Score: 0.9380001562219051

# %%
model=SVC()
classification_Model(model)
# Out:
# Best Model Score: 0.9925325707022561
# Best Accuracy score: 0.9924017790956264
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2712
#            1       0.99      0.99      0.99      2684
#
#     accuracy                           0.99      5396
#    macro avg       0.99      0.99      0.99      5396
# weighted avg       0.99      0.99      0.99      5396
#
# Best confusion Matrix: [[2688   24]
#  [  17 2667]]
#
#
# Best CV Score: 0.9812602087877635

# %%
model=GradientBoostingClassifier()
classification_Model(model)
# Out:
# Best Model Score: 0.998013981569749
# Best Accuracy score: 0.9961082283172721
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      2716
#            1       0.99      1.00      1.00      2680
#
#     accuracy                           1.00      5396
#    macro avg       1.00      1.00      1.00      5396
# weighted avg       1.00      1.00      1.00      5396
#
# Best confusion Matrix: [[2700   16]
#  [   5 2675]]
#
#
# Best CV Score: 0.9910472947753727

# %%
model=AdaBoostClassifier()
classification_Model(model)
# Out:
# Best Model Score: 0.9952335557673975
# Best Accuracy score: 0.992772424017791
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2712
#            1       0.99      0.99      0.99      2684
#
#     accuracy                           0.99      5396
#    macro avg       0.99      0.99      0.99      5396
# weighted avg       0.99      0.99      0.99      5396
#
# Best confusion Matrix: [[2689   23]
#  [  16 2668]]
#
#
# Best CV Score: 0.9848748634410666

# %%
model=BaggingClassifier()
classification_Model(model)
# Out:
# Best Model Score: 0.9994439148395297
# Best Accuracy score: 0.9951816160118606
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      2717
#            1       0.99      1.00      1.00      2679
#
#     accuracy                           1.00      5396
#    macro avg       1.00      1.00      1.00      5396
# weighted avg       1.00      1.00      1.00      5396
#
# Best confusion Matrix: [[2698   19]
#  [   7 2672]]
#
#
# Best CV Score: 0.985653268294245

# %%
model=DecisionTreeClassifier()
classification_Model(model)
# Out:
# Best Model Score: 1.0
# Best Accuracy score: 0.992772424017791
# Best Classification Report:               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2704
#            1       0.99      0.99      0.99      2692
#
#     accuracy                           0.99      5396
#    macro avg       0.99      0.99      0.99      5396
# weighted avg       0.99      0.99      0.99      5396
#
# Best confusion Matrix: [[2685   19]
#  [  20 2672]]
#
#
# Best CV Score: 0.9773126197223448

# %% [markdown]
# ##### Observation
# After evaluating various regression models based on Accuracy score and cross-validation scores, ExtraTreesClassifier is identified as the most suitable model for the given dataset.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
prama={'n_estimators':[10,20,40,100],
      'criterion':['gini','entropy'],
      'max_features':['sqrt','log2']}

# %%
gscv=GridSearchCV(ExtraTreesClassifier(),prama,cv=7)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 20, 40, 100]})

# %%
gscv.best_params_
# Out:
# {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}

# %% [markdown]
# # Final Model Build

# %%
FinalModel=ExtraTreesClassifier (criterion='gini',max_features='sqrt',n_estimators=100)
FinalModel.fit(x_train,y_train)
FinalModel_pred=FinalModel.predict(x_test)
print ('Best Model Score:' , FinalModel.score(x_train,y_train))
print ('Best Accuracy Score:',accuracy_score(FinalModel_pred,y_test))



score=cross_val_score(FinalModel,x,y,cv=7)
print('Best CV Score:', np.mean(score))
# Out:
# Best Model Score: 1.0
# Best Accuracy Score: 0.9992587101556709
# Best CV Score: 0.9877662885678237

# %% [markdown]
# # Save the Model

# %%
import joblib

# %%
joblib.dump(FinalModel,'Extratree_Final_Model.obj')
# Out:
# ['Extratree_Final_Model.obj']

# %%
Avocado_FinalModel=joblib.load('Extratree_Final_Model.obj')
Avocado_FinalModel.predict(x_test)
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %% [markdown]
# # Test The model

# %%
def modeltest(p):
    p=p.reshape(1,-1)
    pred=Avocado_FinalModel.predict (p)
    
    if pred== 1:
        print ('organic')
    else:
        print ('conventional')

# %%
p=np.array([-0.174552,-0.674512,0.145629,-0.145604,-0.474151,-0.874592,-0.645661,-1.217813,-1.695495,-1.047813])

# %%
modeltest(p)
# Out:
# conventional
