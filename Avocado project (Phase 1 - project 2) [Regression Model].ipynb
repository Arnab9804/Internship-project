# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv('avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18239           2  2018-03-11          1.56      22128.42  2162.67  3194.25
# 18240           3  2018-03-04          1.54      17393.30  1832.24  1905.57
# 18241           4  2018-02-25          1.57      18421.24  1974.26  2482.65
# 18242           5  2018-02-18          1.56      17597.12  1892.05  1928.36
# 18243           6  2018-02-11          1.57      15986.17  1924.28  1368.32
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# ...

# %% [markdown]
# ##### Ovbservation:
# 16468 rows along with 3 catagorical column & 10 Numarical column present in this dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# I identified an unnamed column in the dataset that appears to be unnecessary. Consequently, I intend to remove this column from the dataset.

# %%
df.head(2)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74  54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28  44638.81
#
#     4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0  48.16     8696.87     8603.62       93.25          0.0  conventional  2015
# 1  58.33     9505.56     9408.07       97.49          0.0  conventional  2015
#
#    region
# 0  Albany
# 1  Albany

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.sample(5)
# Out:
#              Date  AveragePrice  Total Volume         4046         4225  \
# 10993  2015-02-01          1.67      30193.16      3904.24     14499.51
# 9099   2018-01-21          1.08   42939821.55  14218843.83  13929702.12
# 2636   2015-04-19          1.16     280464.73    182582.22     19553.08
# 12683  2016-07-24          1.98       1509.80       781.44       199.22
# 16478  2017-03-19          1.82      25480.51      7444.63     11899.72
#
#             4770   Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 10993      32.15     11757.26     9989.22     1768.04          0.0
# 9099   928815.12  13862460.48  9866218.28  3789722.90     206519.3
# 2636      138.42     78191.01    56279.47    21911.54          0.0
# 12683       0.00       529.14      516.67       12.47          0.0
# 16478       5.53      6130.63     5945.91      184.72          0.0
#
#                type  year        region
# 10993       organic  2015        Plains
# 9099   conventional  2018       TotalUS
# ...

# %% [markdown]
# ##### Observation:
# I've observed that the data columns are currently in the 'object' datatype. To enhance the dataset, I will be converting these columns to the 'datetime' datatype

# %%
df['New_Date']=df['Date'].str.split('-').str[2]
df['New_Month']=df['Date'].str.split('-').str[1]
df['New_Year']=df['Date'].str.split('-').str[0]

# %%
df.head(5)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region New_Date New_Month New_Year
# 0  Albany       27        12     2015
# 1  Albany       20        12     2015
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
#  13  New_Date      18249 non-null  object
#  14  New_Month     18249 non-null  object
#  15  New_Year      18249 non-null  object
# dtypes: float64(9), int64(1), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# ##### Observation:
# 1. I have successfully extracted the date, month, and year separately.
# 2. The datatype of the newly created column is currently set to 'object.' To align it with the desired format, I need to convert it to an integer ('int') datatype
# 3. Also i have to drop the date column

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    AveragePrice  Total Volume     4046      4225   4770  Total Bags  \
# 0          1.33      64236.62  1036.74  54454.85  48.16     8696.87
# 1          1.35      54876.98   674.28  44638.81  58.33     9505.56
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region New_Date  \
# 0     8603.62       93.25          0.0  conventional  2015  Albany       27
# 1     9408.07       97.49          0.0  conventional  2015  Albany       20
#
#   New_Month New_Year
# 0        12     2015
# 1        12     2015

# %%
df['New_Date']=df['New_Date'].astype(int)
df['New_Month']=df['New_Month'].astype(int)
df['New_Year']=df['New_Year'].astype (int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
#  12  New_Date      18249 non-null  int32
#  13  New_Month     18249 non-null  int32
#  14  New_Year      18249 non-null  int32
# dtypes: float64(9), int32(3), int64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# ##### Observation:
# I need to address two additional categorical columns, namely 'region' and 'type'.

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df.sample(5)
# Out:
#        AveragePrice  Total Volume       4046        4225       4770  \
# 4153           0.99    3173460.24  654357.46  1639480.98  144264.21
# 15473          0.48      50890.73     717.57     4138.84       0.00
# 17012          2.58      19202.54    7333.07     8809.03       0.00
# 5863           1.61     603284.31    5758.71   467084.40    3505.87
# 1883           0.79     657656.23   84270.47   324386.38   31627.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 4153    735357.59   620880.86   113431.73      1045.00  conventional  2016
# 15473    46034.32     1385.06    44649.26         0.00       organic  2017
# 17012     3060.44     3060.44        0.00         0.00       organic  2017
# 5863    126935.33   114534.76    11768.63       631.94  conventional  2017
# 1883    217371.85   211701.25     3997.36      1673.24  conventional  2015
#
#              region  New_Date  New_Month  New_Year
# 4153       Midsouth        14          2      2016
# ...

# %%
print (df['type'].value_counts())
sns.countplot(df,x='type')
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# ##### Observation:
# i will convert conventional column into 0 and organic column into 1

# %%
df['type']=df['type'].map({'conventional':0,'organic':1})

# %%
df.head(3)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  New_Date  \
# 0     8603.62       93.25          0.0     0  2015  Albany        27
# 1     9408.07       97.49          0.0     0  2015  Albany        20
# 2     8042.21      103.14          0.0     0  2015  Albany        13
#
#    New_Month  New_Year
# 0         12      2015
# 1         12      2015
# 2         12      2015

# %%
reg=df['region'].value_counts().reset_index()[:10]
reg
# Out:
#                 index  region
# 0              Albany     338
# 1          Sacramento     338
# 2           Northeast     338
# 3  NorthernNewEngland     338
# 4             Orlando     338
# 5        Philadelphia     338
# 6       PhoenixTucson     338
# 7          Pittsburgh     338
# 8              Plains     338
# 9            Portland     338

# %%
reg_val=df['region'].value_counts().values
reg_val[:10]
# Out:
# array([338, 338, 338, 338, 338, 338, 338, 338, 338, 338], dtype=int64)

# %%
reg_index=df['region'].value_counts().index
reg_index
# Out:
# Index(['Albany', 'Sacramento', 'Northeast', 'NorthernNewEngland', 'Orlando',
#        'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'SanDiego',
#        'Atlanta', 'SanFrancisco', 'Seattle', 'SouthCarolina', 'SouthCentral',
#        'Southeast', 'Spokane', 'StLouis', 'Syracuse', 'Tampa', 'TotalUS',
#        'West', 'NewYork', 'NewOrleansMobile', 'Nashville', 'Midsouth',
#        'BaltimoreWashington', 'Boise', 'Boston', 'BuffaloRochester',
#        'California', 'Charlotte', 'Chicago', 'CincinnatiDayton', 'Columbus',
#        'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids', 'GreatLakes',
#        'HarrisburgScranton', 'HartfordSpringfield', 'Houston', 'Indianapolis',
#        'Jacksonville', 'LasVegas', 'LosAngeles', 'Louisville',
#        'MiamiFtLauderdale', 'WestTexNewMexico'],
#       dtype='object')

# %%
plt.pie(reg_val[:5],labels=reg_index[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1ec8f197710>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'Albany'),
#   Text(-0.3399187231970732, 1.046162158377023, 'Sacramento'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'Northeast'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'NorthernNewEngland'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Orlando')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.00%'),
#   Text(-0.18541021265294902, 0.5706339045692853, '20.00%'),
#   Text(-0.5999999999999993, -2.808802703071063e-08, '20.00%'),
#   Text(-0.1854101592263464, -0.5706339219286397, '20.00%'),
#   Text(0.4854102263424771, -0.3526711104728386, '20.00%')])

# %%
df['New_Year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: New_Year, dtype: int64

# %%
pd.DataFrame(df.groupby(['4046','4225','4770']).size()).reset_index()
# Out:
#               4046         4225        4770  0
# 0             0.00        26.54        0.00  1
# 1             0.00        37.97        0.00  1
# 2             0.00        47.64        0.00  1
# 3             0.00        47.91        0.00  1
# 4             0.00        48.75        0.00  1
# ...            ...          ...         ... ..
# 18243  17076650.82  13549102.59   863471.88  1
# 18244  17787611.93  16602589.04  1118329.50  1
# 18245  18933038.04  18956479.74  1381516.11  1
# 18246  21620180.90  20445501.03  1066830.22  1
# 18247  22743616.17  20328161.55  1664383.09  1
#
# [18248 rows x 4 columns]

# %%
Count=pd.DataFrame(df.groupby(['type','region']).size()).reset_index().rename(columns={0:'Count'})
Count
# Out:
#      type               region  Count
# 0       0               Albany    169
# 1       0              Atlanta    169
# 2       0  BaltimoreWashington    169
# 3       0                Boise    169
# 4       0               Boston    169
# ..    ...                  ...    ...
# 103     1             Syracuse    169
# 104     1                Tampa    169
# 105     1              TotalUS    169
# 106     1                 West    169
# 107     1     WestTexNewMexico    166
#
# [108 rows x 3 columns]

# %%
plt.figure(figsize=(45,20))
sns.barplot(Count,x='region',y='type',palette='bright')
# Out:
# <Axes: xlabel='region', ylabel='type'>

# %%
TotalSale=pd.DataFrame(df.groupby(['Total Bags','Small Bags','XLarge Bags']).size().reset_index().rename(columns={0:'TotalCount'}))
TotalSale
# Out:
#         Total Bags   Small Bags  XLarge Bags  TotalCount
# 0             0.00         0.00         0.00          15
# 1             3.09         3.09         0.00           1
# 2             3.11         3.11         0.00           1
# 3             3.19         3.19         0.00           1
# 4             3.33         3.33         0.00           1
# ...            ...          ...          ...         ...
# 18135  15804696.31  11228049.63    252415.49           1
# 18136  15972492.07  11712807.19    271583.14           1
# 18137  16298296.29  12567155.58    112869.96           1
# 18138  16394524.11  12540327.19    309467.53           1
# 18139  19373134.37  13384586.80    269450.96           1
#
# [18140 rows x 4 columns]

# %% [markdown]
# ##### Observation:
# The count is consistent across all regions of the same type.

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# ...

# %% [markdown]
# ##### Observation:
# 1. No Null value
# 2. some skewness is present in this dataset, to confirm have to perform the skewness check.
# 3. There are instances where certain columns exhibit a variance between the 3rd quartile and the maximum value, indicating the presence of outliers.

# %% [markdown]
# ##### Correlation Check

# %%
df_cor=df.corr()
df_cor
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# New_Date          0.027386     -0.009747 -0.010159 -0.012393 -0.009009
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_cor,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### Observation:
# 1. AveragePrice with type has only some positive correlation present.
# 2. Rest column shows very negative correlation with AveragePrice.
# 3. Also indicate multicollinearity present in this dataset.
# 4. Total Volume with Total Bags,Small Bags,Large Bags,4046,4225,4770 column has very positive correlation.

# %%
sns.scatterplot(df,x='Total Volume',y='Total Bags',hue='type',palette='bright')
# Out:
# <Axes: xlabel='Total Volume', ylabel='Total Bags'>

# %%
sns.scatterplot(df,x='AveragePrice',y='4770',hue='type',palette='bright')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='4770'>

# %% [markdown]
# ##### Now convert the region column into nummarical column using encoding techinique.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la=LabelEncoder()
df['region']=la.fit_transform(df['region'])

# %%
df.head(5)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  New_Date  \
# 0     8603.62       93.25          0.0     0  2015       0        27
# 1     9408.07       97.49          0.0     0  2015       0        20
# 2     8042.21      103.14          0.0     0  2015       0        13
# 3     5677.40      133.76          0.0     0  2015       0         6
# 4     5986.26      197.69          0.0     0  2015       0        29
#
#    New_Month  New_Year
# 0         12      2015
# 1         12      2015
# 2         12      2015
# 3         12      2015
# ...

# %%
plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=15:
        plt.subplot(5,4,p)
        sns.histplot(df[i],kde=True)
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# ##### Checking outliers using boxplot

# %%
plt.figure(figsize=(15,20))
p=1
for i in df.columns:
    if p<=15:
        plt.subplot(5,4,p)
        plt.boxplot(df[i])
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# ##### Observation:
# outlier present in the AveragePrice,Total Volume,4046,4225,4770,Total Bags,Small Bags,XLarge Bags columns

# %% [markdown]
# # Skewness Check

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# New_Date         0.014310
# New_Month        0.106617
# New_Year         0.215339
# dtype: float64

# %% [markdown]
# ##### Observation:
# Skewness is observed in the columns for Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags, and XLarge Bags.
# Addressing skewness in these columns is necessary for further analysis.

# %%
df['Total Volume']=np.sqrt(df['Total Volume'])
df['Total Volume'].skew()
# Out:
# 3.986597233684377

# %%
df['4046']=np.sqrt(df['4046'])
df['4046'].skew()
# Out:
# 3.9529722638123577

# %%
df['4225']=np.sqrt(df['4225'])
df['4225'].skew()
# Out:
# 3.8963552348462307

# %%
df['4770']=np.cbrt(df['4770'])
df['4225'].skew()
# Out:
# 3.8963552348462307

# %%
df['Total Bags']=np.cbrt(df['Total Bags'])
df['Total Bags'].skew()
# Out:
# 2.302176335205292

# %%
df['Small Bags']=np.cbrt(df['Small Bags'])
df['Small Bags'].skew()
# Out:
# 2.2176815955777704

# %%
df['XLarge Bags']=np.cbrt(df['XLarge Bags'])
df['XLarge Bags'].skew()
# Out:
# 2.8422553762768645

# %%
df['Large Bags']=np.cbrt(df['Large Bags'])
df['Large Bags'].skew()
# Out:
# 2.1865135087582934

# %%
df.skew()
# Out:
# AveragePrice    0.580303
# Total Volume    3.986597
# 4046            3.952972
# 4225            3.896355
# 4770            2.316048
# Total Bags      2.302176
# Small Bags      2.217682
# Large Bags      2.186514
# XLarge Bags     2.842255
# type            0.000329
# year            0.215339
# region          0.000030
# New_Date        0.014310
# New_Month       0.106617
# New_Year        0.215339
# dtype: float64

# %%
df['Total Volume']=np.sqrt(df['Total Volume'])
df['4046']=np.sqrt(df['4046'])
df['4225']=np.sqrt(df['4225'])
df['4770']=np.cbrt(df['4770'])
df['Total Bags']=np.cbrt(df['Total Bags'])
df['Small Bags']=np.cbrt(df['Small Bags'])
df['XLarge Bags']=np.cbrt(df['XLarge Bags'])
df['Large Bags']=np.cbrt(df['Large Bags'])

# %%
df.skew()
# Out:
# AveragePrice    0.580303
# Total Volume    1.531126
# 4046            1.541756
# 4225            1.387105
# 4770           -0.014697
# Total Bags      0.473809
# Small Bags      0.043672
# Large Bags     -0.499222
# XLarge Bags     1.023563
# type            0.000329
# year            0.215339
# region          0.000030
# New_Date        0.014310
# New_Month       0.106617
# New_Year        0.215339
# dtype: float64

# %% [markdown]
# ##### Observation:
# Remove the skewness from all the columns

# %%
df.head(2)
# Out:
#    AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0          1.33     15.920096  5.674368  15.275982  1.538031    2.739725
# 1          1.35     15.305501  5.095773  14.535439  1.571123    2.766926
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  New_Date  \
# 0    2.736445    1.655198          0.0     0  2015       0        27
# 1    2.763758    1.663396          0.0     0  2015       0        20
#
#    New_Month  New_Year
# 0         12      2015
# 1         12      2015

# %% [markdown]
# ##### Chacking Null Value

# %%
[features for features in df .columns if df[features].isnull().sum()>0]
# Out:
# []

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ##### Observation:
# No Null data present in this dataset

# %% [markdown]
# # Split the data

# %%
x=df.iloc[:,1:-1]
y=df.iloc[:,0]

# %%
print (x.shape)
print (y.shape)
# Out:
# (18249, 13)
# (18249,)

# %% [markdown]
# ##### Scale the Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.335457 -0.707278  0.063498 -0.085030   -0.575785   -0.362142
# 1         -0.386649 -0.763345 -0.012782 -0.058762   -0.541656   -0.330054
# 2         -0.117007 -0.742638  0.362244  0.057967   -0.600717   -0.386157
# 3         -0.265105 -0.695060  0.177153 -0.028103   -0.726378   -0.507256
# 4         -0.409546 -0.720369 -0.019539 -0.021963   -0.703592   -0.489134
# ...             ...       ...       ...       ...         ...         ...
# 18244     -0.709365 -0.605342 -0.865869 -1.305897   -0.403704   -0.209344
# 18245     -0.757290 -0.687792 -0.721632 -1.305897   -0.551537   -0.348411
# 18246     -0.759271 -0.687766 -0.785108  0.344977   -0.546203   -0.332217
# 18247     -0.721727 -0.651324 -0.748886  0.344742   -0.485960   -0.275855
# 18248     -0.703635 -0.546353 -0.792358  0.142728   -0.450129   -0.241430
#
#        Large Bags  XLarge Bags      type      year    region  New_Date  \
# ...

# %% [markdown]
# # Checking VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF Factor']=[variance_inflation_factor (x.values,i) for i in range (len (x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Factor      Features
# 0   135.592511  Total Volume
# 1    21.178060          4046
# 2    34.747610          4225
# 3     4.046087          4770
# 4    32.870503    Total Bags
# 5    13.374617    Small Bags
# 6     2.928120    Large Bags
# 7     2.398963   XLarge Bags
# 8     3.019704          type
# 9     1.476678          year
# 10    1.119482        region
# 11    1.000964      New_Date
# 12    1.060594     New_Month

# %% [markdown]
# ##### Observation:
# 1. My VIF thresold value is 10
# 2. The presence of substantial multicollinearity among the columns representing Total Volume,Total Bags and Small Bags is evident

# %%
df=df.drop('Total Volume',axis=1)

# %% [markdown]
# ##### Again Split the data

# %%
x=df.iloc[:,1:-1]
y=df.iloc[:,0]
print (x.shape)
print (y.shape)
# Out:
# (18249, 12)
# (18249,)

# %% [markdown]
# ##### Again scale the dataset

# %%
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#            4046      4225      4770  Total Bags  Small Bags  Large Bags  \
# 0     -0.707278  0.063498 -0.085030   -0.575785   -0.362142   -0.531393
# 1     -0.763345 -0.012782 -0.058762   -0.541656   -0.330054   -0.524247
# 2     -0.742638  0.362244  0.057967   -0.600717   -0.386157   -0.515144
# 3     -0.695060  0.177153 -0.028103   -0.726378   -0.507256   -0.472390
# 4     -0.720369 -0.019539 -0.021963   -0.703592   -0.489134   -0.405775
# ...         ...       ...       ...         ...         ...         ...
# 18244 -0.605342 -0.865869 -1.305897   -0.403704   -0.209344   -0.263534
# 18245 -0.687792 -0.721632 -1.305897   -0.551537   -0.348411   -0.316827
# 18246 -0.687766 -0.785108  0.344977   -0.546203   -0.332217   -0.652664
# 18247 -0.651324 -0.748886  0.344742   -0.485960   -0.275855   -0.627916
# 18248 -0.546353 -0.792358  0.142728   -0.450129   -0.241430   -0.722200
#
#        XLarge Bags      type      year    region  New_Date  New_Month
# ...

# %%
vif=pd.DataFrame()
vif['VIF Factor']=[variance_inflation_factor (x.values,i) for i in range (len (x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Factor     Features
# 0     4.525966         4046
# 1     5.362807         4225
# 2     3.947094         4770
# 3    23.186629   Total Bags
# 4    13.358075   Small Bags
# 5     2.911104   Large Bags
# 6     2.362008  XLarge Bags
# 7     2.913884         type
# 8     1.472723         year
# 9     1.109884       region
# 10    1.000938     New_Date
# 11    1.058128    New_Month

# %% [markdown]
# ##### Observation :
# Due to a high Variance Inflation Factor (VIF) in the Total Bags column, I will opt to drop it for further analysis

# %%
df=df.drop('Total Bags',axis=1)

# %%
df.head(2)
# Out:
#    AveragePrice      4046       4225      4770  Small Bags  Large Bags  \
# 0          1.33  5.674368  15.275982  1.538031    2.736445    1.655198
# 1          1.35  5.095773  14.535439  1.571123    2.763758    1.663396
#
#    XLarge Bags  type  year  region  New_Date  New_Month  New_Year
# 0          0.0     0  2015       0        27         12      2015
# 1          0.0     0  2015       0        20         12      2015

# %% [markdown]
# ##### Again Split the data

# %%
x=df.iloc[:,1:-1]
y=df.iloc[:,0]
print (x.shape)
print (y.shape)
# Out:
# (18249, 11)
# (18249,)

# %% [markdown]
# ##### Again scale the dataset

# %%
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#            4046      4225      4770  Small Bags  Large Bags  XLarge Bags  \
# 0     -0.707278  0.063498 -0.085030   -0.362142   -0.531393    -0.676729
# 1     -0.763345 -0.012782 -0.058762   -0.330054   -0.524247    -0.676729
# 2     -0.742638  0.362244  0.057967   -0.386157   -0.515144    -0.676729
# 3     -0.695060  0.177153 -0.028103   -0.507256   -0.472390    -0.676729
# 4     -0.720369 -0.019539 -0.021963   -0.489134   -0.405775    -0.676729
# ...         ...       ...       ...         ...         ...          ...
# 18244 -0.605342 -0.865869 -1.305897   -0.209344   -0.263534    -0.676729
# 18245 -0.687792 -0.721632 -1.305897   -0.348411   -0.316827    -0.676729
# 18246 -0.687766 -0.785108  0.344977   -0.332217   -0.652664    -0.676729
# 18247 -0.651324 -0.748886  0.344742   -0.275855   -0.627916    -0.676729
# 18248 -0.546353 -0.792358  0.142728   -0.241430   -0.722200    -0.676729
#
#            type      year    region  New_Date  New_Month
# ...

# %%
vif=pd.DataFrame()
vif['VIF Factor']=[variance_inflation_factor (x.values,i) for i in range (len (x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Factor     Features
# 0     4.354490         4046
# 1     4.901356         4225
# 2     3.937100         4770
# 3     4.796522   Small Bags
# 4     1.882859   Large Bags
# 5     2.361355  XLarge Bags
# 6     2.912698         type
# 7     1.426814         year
# 8     1.109325       region
# 9     1.000882     New_Date
# 10    1.057249    New_Month

# %% [markdown]
# ##### Again Checking Correlation after removing the the skewness & scaling the data

# %%
df_cor=df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(df_cor,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### observation:
# 1. it is confirmed that there is no multicollinearity within the dataset at present.

# %% [markdown]
# # Model Build

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
maxACC=0
maxRE=0
for i in range (1,200):
    x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit (x_train,y_train)
    predict_lr=lr.predict(x_test)
    acc=r2_score(y_test,predict_lr)
    if acc>maxACC:
        maxACC=acc
        maxRE=i
print('Maximum r2 score is:',maxACC,'On Random Estate:',maxRE)
print ("Model build score:",lr.score(x_train,y_train))
# Out:
# Maximum r2 score is: 0.5410774962043001 On Random Estate: 113
# Model build score: 0.5194196342949248

# %% [markdown]
# ##### Try with Different Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor

from sklearn.model_selection import cross_val_score

# %%
def regression_Model(model):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=6)
    model.fit (x_train, y_train)
    pred_model=model.predict(x_test)
    print ("Best Model Score:",model.score(x_train,y_train))

    print ('Best R2 score:',r2_score(pred_model,y_test))
    
    print ('Mean absolute Error Score:', mean_absolute_error(pred_model,y_test))
    
    print ('Mean squared Error Score:', mean_squared_error(pred_model,y_test))
    
    print ('Root Mean squared error:',np.sqrt(mean_squared_error(pred_model,y_test)))
    print ('\n')
    
    score=cross_val_score(model,x,y,cv=7)
    print ("Best CV Score:",np.mean(score))
    print ("Difference between r2 score and cv score:", r2_score(pred_model,y_test) - np.mean(score))

# %%
model=LinearRegression()
regression_Model(model)
# Out:
# Best Model Score: 0.5118398757430944
# Best R2 score: 0.08566437457482634
# Mean absolute Error Score: 0.2132725705203008
# Mean squared Error Score: 0.07673645229330785
# Root Mean squared error: 0.2770134514663644
#
#
# Best CV Score: 0.07895087582169699
# Difference between r2 score and cv score: 0.006713498753129349

# %%
model=DecisionTreeRegressor()
regression_Model(model)
# Out:
# Best Model Score: 1.0
# Best R2 score: 0.7436419216634856
# Mean absolute Error Score: 0.13155068493150684
# Mean squared Error Score: 0.04179813698630137
# Root Mean squared error: 0.2044459268029113
#
#
# Best CV Score: -0.08983227610951652
# Difference between r2 score and cv score: 0.8334741977730021

# %%
model=KNeighborsRegressor()
regression_Model(model)
# Out:
# Best Model Score: 0.8396309396823837
# Best R2 score: 0.6639073946513637
# Mean absolute Error Score: 0.14520255707762555
# Mean squared Error Score: 0.040367780821917804
# Root Mean squared error: 0.20091734823533233
#
#
# Best CV Score: 0.05239317464231615
# Difference between r2 score and cv score: 0.6115142200090475

# %%
model=Ridge()
regression_Model(model)
# Out:
# Best Model Score: 0.5118398585500861
# Best R2 score: 0.08546105337760512
# Mean absolute Error Score: 0.21327261608710846
# Mean squared Error Score: 0.07673696451521446
# Root Mean squared error: 0.2770143760082037
#
#
# Best CV Score: 0.0790092193510512
# Difference between r2 score and cv score: 0.006451834026553929

# %%
model=Lasso()
regression_Model(model)
# Out:
# Best Model Score: 0.0
# Best R2 score: 0.0
# Mean absolute Error Score: 0.3275606832657374
# Mean squared Error Score: 0.16514553756780914
# Root Mean squared error: 0.40638102510797564
#
#
# Best CV Score: -1.2745062939401588
# Difference between r2 score and cv score: 1.2745062939401588

# %%
model=ExtraTreesRegressor()
regression_Model(model)
# Out:
# Best Model Score: 1.0
# Best R2 score: 0.896312748472352
# Mean absolute Error Score: 0.08234672146118721
# Mean squared Error Score: 0.013962295837442918
# Root Mean squared error: 0.1181621590757503
#
#
# Best CV Score: 0.44197137500121414
# Difference between r2 score and cv score: 0.45434137347113784

# %%
model=SVR()
regression_Model(model)
# Out:
# Best Model Score: 0.7860904507188226
# Best R2 score: 0.6687273208073188
# Mean absolute Error Score: 0.14127862911724612
# Mean squared Error Score: 0.03749626008522309
# Root Mean squared error: 0.19363951065116616
#
#
# Best CV Score: 0.12813609768578663
# Difference between r2 score and cv score: 0.5405912231215322

# %%
model=SGDRegressor()
regression_Model(model)
# Out:
# Best Model Score: 0.5106818394323154
# Best R2 score: 0.1427691705188896
# Mean absolute Error Score: 0.21354901277492708
# Mean squared Error Score: 0.07678754967470387
# Root Mean squared error: 0.27710566517973584
#
#
# Best CV Score: 0.06048391461044089
# Difference between r2 score and cv score: 0.0822852559084487

# %% [markdown]
# ##### Observation
# After evaluating various regression models based on the difference in R2 scores and cross-validation scores, Ridge is identified as the most suitable model for the given dataset.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
prama={'alpha':[0.0,1.0,1.2,1.5,2.0,1.5,3,5,8,10],
      'fit_intercept':[True,False],
      'solver':['auto','svd','cholesky']}

# %%
gscv=GridSearchCV(Ridge(),prama,cv=7)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=Ridge(),
#              param_grid={'alpha': [0.0, 1.0, 1.2, 1.5, 2.0, 1.5, 3, 5, 8, 10],
#                          'fit_intercept': [True, False],
#                          'solver': ['auto', 'svd', 'cholesky']})

# %%
gscv.best_params_
# Out:
# {'alpha': 5, 'fit_intercept': True, 'solver': 'auto'}

# %% [markdown]
# # Final Model Build

# %%
FinalModel=Ridge(alpha=5,fit_intercept=True,solver='auto')
FinalModel.fit(x_train,y_train)
FinalModel_pred=FinalModel.predict(x_test)
print ('Model Score:',FinalModel.score(x_train,y_train))
print ('Best R2 Score:' , r2_score(FinalModel_pred,y_test))


score=cross_val_score(FinalModel,x,y,cv=7)
print('Best CV Score:', np.mean(score))
print ('Difference between r2 score and CV score:', r2_score(FinalModel_pred,y_test) - np.mean(score))
# Out:
# Model Score: 0.519419205415313
# Best R2 Score: 0.10177792414196729
# Best CV Score: 0.07924124975448209
# Difference between r2 score and CV score: 0.022536674387485203

# %%
sns.scatterplot(x=FinalModel_pred,y=y_test,palette='bright')
# Out:
# <Axes: ylabel='AveragePrice'>

# %% [markdown]
# # Save the Model

# %%
import joblib

# %%
joblib.dump(FinalModel,'Final_Ridge_Model.obj')
# Out:
# ['Final_Ridge_Model.obj']

# %%
Final_Model=joblib.load('Final_Ridge_Model.obj')
Final_Model.predict(x_test)
# Out:
# array([1.54454128, 1.22382312, 1.36806927, ..., 1.62983396, 1.68550933,
#        1.53894967])

# %% [markdown]
# # Test The model

# %%
def testModel(p):
    p=p.reshape (1,-1)
    pred=FinalModel.predict(p)
    return pred

# %%
p=np.array([-0.701248,0.163498,-0.078930,-0.314562,-0.631393,-0.674899,-0.799836,-1.245792,-1.774582,1.297847,1.647632])

# %%
testModel(p)
# Out:
# array([1.40964186])
